# %% [markdown]
# # Take the frame based detections and turn them into movement trajectories
# (For speed, uses multiprocessing and breaks up observations into 10 overlapping temporal groups to process seperately since tracks are much shorter in time than the total length of the obervations.)

# %%
import glob
import os

import matplotlib.pyplot as plt
from multiprocessing import Pool
import numpy as np

import bat_functions as kbf
# Out:
# C:\Users\Edward\anaconda3\envs\Eidolon\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Edward\anaconda3\envs\Eidolon\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\Edward\anaconda3\envs\Eidolon\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
base_folder = r"D:\kasanka-bats"
# Which day to track
day = "20211221"
#"20211201"
#"20211207"
#"20211215"
camera_folders = sorted(glob.glob(os.path.join(base_folder, day, '*')))

# %%
base_folder = r"D:\kasanka-bats"
# Which days to track
days = ["20211201", "20211207", "20211215", "20211221"]
camera_folders = []

for day in days:
    print(day)
    day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, '*')))
    camera_folders.extend(day_camera_folders)
    #day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, 'MusolaTower*')))
    #camera_folders.extend(day_camera_folders)
    #day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, 'MusolaPath2*')))
    #camera_folders.extend(day_camera_folders)
    #day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, 'Sunset*')))
    #camera_folders.extend(day_camera_folders)
# Out:
# 20211201
# 20211207
# 20211215
# 20211221

# %%
print(camera_folders)
# Out:
# ['D:\\kasanka-bats\\20211201\\BBC', 'D:\\kasanka-bats\\20211201\\Chinyangali', 'D:\\kasanka-bats\\20211201\\FibweParking', 'D:\\kasanka-bats\\20211201\\FibwePublic', 'D:\\kasanka-bats\\20211201\\MusolaParking', 'D:\\kasanka-bats\\20211201\\MusolaPath', 'D:\\kasanka-bats\\20211201\\MusolaTower', 'D:\\kasanka-bats\\20211201\\NotChinyangaliLocB', 'D:\\kasanka-bats\\20211201\\Puku', 'D:\\kasanka-bats\\20211201\\Sunset', 'D:\\kasanka-bats\\20211207\\BBC', 'D:\\kasanka-bats\\20211207\\Chinyangali', 'D:\\kasanka-bats\\20211207\\FibweParking', 'D:\\kasanka-bats\\20211207\\FibwePublic', 'D:\\kasanka-bats\\20211207\\MusolaParking', 'D:\\kasanka-bats\\20211207\\MusolaPath', 'D:\\kasanka-bats\\20211207\\MusolaTower', 'D:\\kasanka-bats\\20211207\\NotChinyangaliLocB', 'D:\\kasanka-bats\\20211207\\Puku', 'D:\\kasanka-bats\\20211207\\Sunset', 'D:\\kasanka-bats\\20211215\\BBC', 'D:\\kasanka-bats\\20211215\\Chinyangali', 'D:\\kasanka-bats\\20211215\\FibweManagement', 'D:\\kasanka-bats\\20211215\\FibweParking', 'D:\\kasanka-bats\\20211215\\FibwePublic', 'D:\\kasanka-bats\\20211215\\KKCamera', 'D:\\kasanka-bats\\20211215\\MusolaParking', 'D:\\kasanka-bats\\20211215\\MusolaPath2', 'D:\\kasanka-bats\\20211215\\PukuLocB', 'D:\\kasanka-bats\\20211215\\Sunset', 'D:\\kasanka-bats\\20211221\\BBC2', 'D:\\kasanka-bats\\20211221\\ChinyangaliB', 'D:\\kasanka-bats\\20211221\\FibweManagement', 'D:\\kasanka-bats\\20211221\\FibweParking', 'D:\\kasanka-bats\\20211221\\KKCamera', 'D:\\kasanka-bats\\20211221\\NotChinyangaliLocC', 'D:\\kasanka-bats\\20211221\\NotMusolaParking', 'D:\\kasanka-bats\\20211221\\NotMusolaPath', 'D:\\kasanka-bats\\20211221\\PukuLocC', 'D:\\kasanka-bats\\20211221\\Sunset']

# %%
n_camera_folders = []
for folder in camera_folders:
    tracks_file = os.path.join(folder, "raw_tracks.npy")
    if os.path.exists(tracks_file):
        # Skip videos that have already been tracked
        continue
    else:
        n_camera_folders.append(folder)

print("Videos to track...")
print(*n_camera_folders, sep='\n')
# Out:
# Videos to track...
# D:\kasanka-bats\20211201\BBC
# D:\kasanka-bats\20211201\Chinyangali
# D:\kasanka-bats\20211201\FibweParking
# D:\kasanka-bats\20211201\FibwePublic
# D:\kasanka-bats\20211201\MusolaParking
# D:\kasanka-bats\20211201\MusolaPath
# D:\kasanka-bats\20211201\NotChinyangaliLocB
# D:\kasanka-bats\20211207\BBC
# D:\kasanka-bats\20211207\Chinyangali
# D:\kasanka-bats\20211207\FibweParking
# D:\kasanka-bats\20211207\FibwePublic
# D:\kasanka-bats\20211207\MusolaParking
# D:\kasanka-bats\20211207\MusolaPath
# D:\kasanka-bats\20211207\NotChinyangaliLocB
# D:\kasanka-bats\20211215\BBC
# D:\kasanka-bats\20211215\Chinyangali
# D:\kasanka-bats\20211215\FibweManagement
# D:\kasanka-bats\20211215\FibweParking
# D:\kasanka-bats\20211215\FibwePublic
# D:\kasanka-bats\20211215\KKCamera
# D:\kasanka-bats\20211215\MusolaParking

# %%
def track(camera_dict):
    camera_folder = camera_dict['camera_folder']
    if glob.glob(os.path.join(camera_folder, 'first_frame*.npy')):
        print(f"Skipping {os.path.basename(camera_folder)} since files exist.")
        return
    first_frame = camera_dict['first_frame']
    max_frame = camera_dict['max_frame']
    print(f"{os.path.basename(camera_folder)} begun.")
    contours_files = sorted(
        glob.glob(os.path.join(camera_folder, 'contours-compressed-*.npy'))
    )
    if contours_files:
        contours_files = contours_files[1:]
        centers = np.load(os.path.join(camera_folder, 'centers.npy'), allow_pickle=True)
        sizes = np.load(os.path.join(camera_folder, 'size.npy'), allow_pickle=True)
        tracks_file = os.path.join(camera_folder, f'first_frame_{first_frame}_max_val_{max_frame}_raw_tracks.npy')
        raw_tracks = kbf.find_tracks(first_frame, centers, contours_files=contours_files, 
                                     sizes_list=sizes, tracks_file=tracks_file,
                                     max_frame=max_frame)
    else:
        print("Missing contour files.")

# %%
camera_dicts = []
for camera_folder in n_camera_folders:
    # To speed up processing, detections found in each observation are split
    # into 10 groups by time with 15 seconds of overlap in each group
    centers_file = os.path.join(camera_folder, 'centers.npy')
    centers = np.load(centers_file, allow_pickle=True)
    max_vals = np.linspace(0, len(centers), 10, dtype=int)[1:].tolist()
    max_vals[-1] = None
    min_vals = np.linspace(0, len(centers), 10, dtype=int)[:-1]
    # 15 second overlap
    min_vals[1:] = min_vals[1:] - 450
    for min_val, max_val in zip(min_vals, max_vals):
        min_val = np.max([min_val, 0])
        camera_dict = {'camera_folder': camera_folder,
                       'first_frame': min_val,
                       'max_frame': max_val}
        if max_val is None:
            tracks_basename = f'first_frame_{min_val:06d}_max_val_{max_val}_raw_tracks.npy'
        else:
            tracks_basename = f'first_frame_{min_val:06d}_max_val_{max_val:06d}_raw_tracks.npy'
        tracks_file = os.path.join(camera_folder, tracks_basename)
        if not os.path.exists(tracks_file):
            print(tracks_file)
            camera_dicts.append(camera_dict)
# Out:
# D:\kasanka-bats\20211201\BBC\first_frame_000000_max_val_004713_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_004263_max_val_009426_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_008976_max_val_014139_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_013689_max_val_018852_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_018402_max_val_023566_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_023116_max_val_028279_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_027829_max_val_032992_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_032542_max_val_037705_raw_tracks.npy
# D:\kasanka-bats\20211201\BBC\first_frame_037255_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_000000_max_val_006320_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_005870_max_val_012640_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_012190_max_val_018961_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_018511_max_val_025281_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_024831_max_val_031601_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_031151_max_val_037922_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_037472_max_val_044242_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_043792_max_val_050562_raw_tracks.npy
# D:\kasanka-bats\20211201\Chinyangali\first_frame_050112_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_000000_max_val_004513_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_004063_max_val_009026_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_008576_max_val_013540_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_013090_max_val_018053_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_017603_max_val_022566_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_022116_max_val_027080_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_026630_max_val_031593_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_031143_max_val_036106_raw_tracks.npy
# D:\kasanka-bats\20211201\FibweParking\first_frame_035656_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_000000_max_val_005365_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_004915_max_val_010731_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_010281_max_val_016097_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_015647_max_val_021463_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_021013_max_val_026829_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_026379_max_val_032195_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_031745_max_val_037561_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_037111_max_val_042927_raw_tracks.npy
# D:\kasanka-bats\20211201\FibwePublic\first_frame_042477_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_000000_max_val_006223_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_005773_max_val_012446_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_011996_max_val_018670_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_018220_max_val_024893_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_024443_max_val_031116_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_030666_max_val_037340_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_036890_max_val_043563_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_043113_max_val_049786_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaParking\first_frame_049336_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_000000_max_val_009366_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_008916_max_val_018732_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_018282_max_val_028099_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_027649_max_val_037465_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_037015_max_val_046831_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_046381_max_val_056198_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_055748_max_val_065564_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_065114_max_val_074930_raw_tracks.npy
# D:\kasanka-bats\20211201\MusolaPath\first_frame_074480_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_000000_max_val_012779_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_012329_max_val_025559_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_025109_max_val_038338_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_037888_max_val_051118_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_050668_max_val_063897_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_063447_max_val_076677_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_076227_max_val_089456_raw_tracks.npy
# D:\kasanka-bats\20211201\NotChinyangaliLocB\first_frame_089006_max_val_102236_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_000000_max_val_004713_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_004263_max_val_009426_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_008976_max_val_014139_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_013689_max_val_018852_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_018402_max_val_023566_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_023116_max_val_028279_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_027829_max_val_032992_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_032542_max_val_037705_raw_tracks.npy
# D:\kasanka-bats\20211207\BBC\first_frame_037255_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_000000_max_val_006413_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_005963_max_val_012826_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_012376_max_val_019240_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_018790_max_val_025653_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_025203_max_val_032066_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_031616_max_val_038480_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_038030_max_val_044893_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_044443_max_val_051306_raw_tracks.npy
# D:\kasanka-bats\20211207\Chinyangali\first_frame_050856_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_000000_max_val_009026_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_008576_max_val_018053_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_017603_max_val_027080_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_026630_max_val_036106_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_035656_max_val_045133_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_044683_max_val_054160_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_053710_max_val_063186_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_062736_max_val_072213_raw_tracks.npy
# D:\kasanka-bats\20211207\FibweParking\first_frame_071763_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_000000_max_val_003937_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_003487_max_val_007875_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_007425_max_val_011812_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_011362_max_val_015750_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_015300_max_val_019687_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_019237_max_val_023625_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_023175_max_val_027562_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_027112_max_val_031500_raw_tracks.npy
# D:\kasanka-bats\20211207\FibwePublic\first_frame_031050_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_000000_max_val_005530_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_005080_max_val_011060_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_010610_max_val_016590_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_016140_max_val_022120_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_021670_max_val_027650_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_027200_max_val_033180_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_032730_max_val_038710_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_038260_max_val_044240_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaParking\first_frame_043790_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_000000_max_val_010470_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_010020_max_val_020940_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_020490_max_val_031410_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_030960_max_val_041880_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_041430_max_val_052350_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_051900_max_val_062820_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_062370_max_val_073290_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_072840_max_val_083760_raw_tracks.npy
# D:\kasanka-bats\20211207\MusolaPath\first_frame_083310_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_000000_max_val_006442_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_005992_max_val_012884_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_012434_max_val_019327_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_018877_max_val_025769_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_025319_max_val_032211_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_031761_max_val_038654_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_038204_max_val_045096_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_044646_max_val_051538_raw_tracks.npy
# D:\kasanka-bats\20211207\NotChinyangaliLocB\first_frame_051088_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_000000_max_val_004292_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_003842_max_val_008584_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_008134_max_val_012876_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_012426_max_val_017168_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_016718_max_val_021460_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_021010_max_val_025752_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_025302_max_val_030044_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_029594_max_val_034336_raw_tracks.npy
# D:\kasanka-bats\20211215\BBC\first_frame_033886_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_000000_max_val_006413_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_005963_max_val_012826_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_012376_max_val_019240_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_018790_max_val_025653_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_025203_max_val_032066_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_031616_max_val_038480_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_038030_max_val_044893_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_044443_max_val_051306_raw_tracks.npy
# D:\kasanka-bats\20211215\Chinyangali\first_frame_050856_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_000000_max_val_001380_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_000930_max_val_002760_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_002310_max_val_004141_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_003691_max_val_005521_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_005071_max_val_006902_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_006452_max_val_008282_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_007832_max_val_009663_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_009213_max_val_011043_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweManagement\first_frame_010593_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_000000_max_val_004513_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_004063_max_val_009026_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_008576_max_val_013540_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_013090_max_val_018053_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_017603_max_val_022566_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_022116_max_val_027080_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_026630_max_val_031593_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_031143_max_val_036106_raw_tracks.npy
# D:\kasanka-bats\20211215\FibweParking\first_frame_035656_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_000000_max_val_003937_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_003487_max_val_007875_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_007425_max_val_011812_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_011362_max_val_015750_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_015300_max_val_019687_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_019237_max_val_023625_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_023175_max_val_027562_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_027112_max_val_031500_raw_tracks.npy
# D:\kasanka-bats\20211215\FibwePublic\first_frame_031050_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_000000_max_val_005638_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_005188_max_val_011276_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_010826_max_val_016915_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_016465_max_val_022553_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_022103_max_val_028192_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_027742_max_val_033830_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_033380_max_val_039469_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_039019_max_val_045107_raw_tracks.npy
# D:\kasanka-bats\20211215\KKCamera\first_frame_044657_max_val_None_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_000000_max_val_005356_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_004906_max_val_010713_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_010263_max_val_016070_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_015620_max_val_021426_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_020976_max_val_026783_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_026333_max_val_032140_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_031690_max_val_037496_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_037046_max_val_042853_raw_tracks.npy
# D:\kasanka-bats\20211215\MusolaParking\first_frame_042403_max_val_None_raw_tracks.npy

# %%
print(camera_dicts)
#with Pool(processes=5) as pool:
#    pool.map(track, camera_dicts)
# Out:
# [{'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 0, 'max_frame': 4713}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 4263, 'max_frame': 9426}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 8976, 'max_frame': 14139}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 13689, 'max_frame': 18852}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 18402, 'max_frame': 23566}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 23116, 'max_frame': 28279}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 27829, 'max_frame': 32992}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 32542, 'max_frame': 37705}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\BBC', 'first_frame': 37255, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 0, 'max_frame': 6320}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 5870, 'max_frame': 12640}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 12190, 'max_frame': 18961}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 18511, 'max_frame': 25281}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 24831, 'max_frame': 31601}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 31151, 'max_frame': 37922}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 37472, 'max_frame': 44242}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 43792, 'max_frame': 50562}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\Chinyangali', 'first_frame': 50112, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 0, 'max_frame': 4513}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 4063, 'max_frame': 9026}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 8576, 'max_frame': 13540}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 13090, 'max_frame': 18053}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 17603, 'max_frame': 22566}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 22116, 'max_frame': 27080}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 26630, 'max_frame': 31593}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 31143, 'max_frame': 36106}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibweParking', 'first_frame': 35656, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 0, 'max_frame': 5365}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 4915, 'max_frame': 10731}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 10281, 'max_frame': 16097}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 15647, 'max_frame': 21463}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 21013, 'max_frame': 26829}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 26379, 'max_frame': 32195}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 31745, 'max_frame': 37561}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 37111, 'max_frame': 42927}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\FibwePublic', 'first_frame': 42477, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\MusolaParking', 'first_frame': 0, 'max_frame': 6223}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\MusolaParking', 'first_frame': 5773, 'max_frame': 12446}, {'camera_folder': 'D:\\kasanka-bats\\20211201\\MusolaParking', 'first_frame': 11996, 'max_frame': 18670}, {'camera_folder': 'D:\\kasanka-bats\\2 ...

# %%
for camera_dict in camera_dicts:
    track(camera_dict)
# Out:
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping MusolaPath since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping NotChinyangaliLocB since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweManagement since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibweParking since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping FibwePublic since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping KKCamera since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.
# Skipping MusolaParking since files exist.

# %% [markdown]
# ### Now connect the 10 sections of the observation that were tracked seperately together

# %%
def combine_overlapping_tracks(observation_folder, first_group=0, last_group=None, save=False):
    track_files = glob.glob(os.path.join(observation_folder, 'first_frame*.npy'))
    track_files = sorted(track_files, key=lambda f: int(f.split('_')[-6]))

    track_groups = []
    for file in track_files:
        track_groups.append(np.load(file, allow_pickle=True))
        
        
    for track_file in track_files:
        print(os.path.basename(track_file))
        
    first_overlap_frames = [int(f.split('_')[-6]) for f in track_files[1:]]
    first_overlap_frames.append(None)
    print(first_overlap_frames)
        
    all_tracks = []

    total_tracks = 0
    for group_ind, track_group in enumerate(track_groups[first_group:last_group]):
        if group_ind >= len(track_groups) -1:
            for track in track_group:
                if type(track['track']) == list:
                    track['track'] = np.stack(track['track'])
                    track['pos_index'] = np.stack(track['pos_index'])
                    if 'size' in track:
                        track['size'] = np.stack(track['size'])
                all_tracks.append(track)
            total_tracks += len(track_group)
            break

        for track_ind, track in enumerate(track_group):
            if track['first_frame'] < first_overlap_frames[first_group + group_ind]:
                all_tracks.append(track)


    all_tracks_file = os.path.join(observation_folder, 'raw_tracks.npy')
    if save:
        np.save(all_tracks_file, all_tracks)
        print('saved')

# %%
observation_folders = []
for folder in camera_folders:
    if not os.path.exists(os.path.join(folder, 'first_frame*.npy')):
        observation_folders.append(folder)

# %%
print(observation_folders)
# Out:
# ['D:\\kasanka-bats\\20211201\\BBC', 'D:\\kasanka-bats\\20211201\\Chinyangali', 'D:\\kasanka-bats\\20211201\\FibweParking', 'D:\\kasanka-bats\\20211201\\FibwePublic', 'D:\\kasanka-bats\\20211201\\MusolaParking', 'D:\\kasanka-bats\\20211201\\MusolaPath', 'D:\\kasanka-bats\\20211201\\MusolaTower', 'D:\\kasanka-bats\\20211201\\NotChinyangaliLocB', 'D:\\kasanka-bats\\20211201\\Puku', 'D:\\kasanka-bats\\20211201\\Sunset', 'D:\\kasanka-bats\\20211207\\BBC', 'D:\\kasanka-bats\\20211207\\Chinyangali', 'D:\\kasanka-bats\\20211207\\FibweParking', 'D:\\kasanka-bats\\20211207\\FibwePublic', 'D:\\kasanka-bats\\20211207\\MusolaParking', 'D:\\kasanka-bats\\20211207\\MusolaPath', 'D:\\kasanka-bats\\20211207\\MusolaTower', 'D:\\kasanka-bats\\20211207\\NotChinyangaliLocB', 'D:\\kasanka-bats\\20211207\\Puku', 'D:\\kasanka-bats\\20211207\\Sunset', 'D:\\kasanka-bats\\20211215\\BBC', 'D:\\kasanka-bats\\20211215\\Chinyangali', 'D:\\kasanka-bats\\20211215\\FibweManagement', 'D:\\kasanka-bats\\20211215\\FibweParking', 'D:\\kasanka-bats\\20211215\\FibwePublic', 'D:\\kasanka-bats\\20211215\\KKCamera', 'D:\\kasanka-bats\\20211215\\MusolaParking', 'D:\\kasanka-bats\\20211215\\MusolaPath2', 'D:\\kasanka-bats\\20211215\\PukuLocB', 'D:\\kasanka-bats\\20211215\\Sunset', 'D:\\kasanka-bats\\20211221\\BBC2', 'D:\\kasanka-bats\\20211221\\ChinyangaliB', 'D:\\kasanka-bats\\20211221\\FibweManagement', 'D:\\kasanka-bats\\20211221\\FibweParking', 'D:\\kasanka-bats\\20211221\\KKCamera', 'D:\\kasanka-bats\\20211221\\NotChinyangaliLocC', 'D:\\kasanka-bats\\20211221\\NotMusolaParking', 'D:\\kasanka-bats\\20211221\\NotMusolaPath', 'D:\\kasanka-bats\\20211221\\PukuLocC', 'D:\\kasanka-bats\\20211221\\Sunset']

# %%
for folder in observation_folders:
    combine_overlapping_tracks(folder, save=True)
# Out:
# first_frame_0_max_val_4713_raw_tracks.npy
# first_frame_4263_max_val_9426_raw_tracks.npy
# first_frame_8976_max_val_14139_raw_tracks.npy
# first_frame_13689_max_val_18852_raw_tracks.npy
# first_frame_18402_max_val_23566_raw_tracks.npy
# first_frame_23116_max_val_28279_raw_tracks.npy
# first_frame_27829_max_val_32992_raw_tracks.npy
# first_frame_32542_max_val_37705_raw_tracks.npy
# first_frame_37255_max_val_None_raw_tracks.npy
# [4263, 8976, 13689, 18402, 23116, 27829, 32542, 37255, None]
# saved
