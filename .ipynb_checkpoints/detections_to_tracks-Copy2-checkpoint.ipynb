# %% [markdown]
# # Take the frame based detections and turn them into movement trajectories
# (For speed, uses multiprocessing and breaks up observations into 10 overlapping temporal groups to process seperately since tracks are much shorter in time than the total length of the obervations.)

# %%
import glob
import os

import matplotlib.pyplot as plt
from multiprocessing import Pool
import numpy as np

import bat_functions as kbf
# Out:
# C:\Users\Edward\anaconda3\envs\Eidolon\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Edward\anaconda3\envs\Eidolon\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\Edward\anaconda3\envs\Eidolon\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
base_folder = "D:/kasanka-bats"
# Which day to track
day = "20211221"
#"20211201"
#"20211207"
#"20211215"
camera_folders = sorted(glob.glob(os.path.join(base_folder, day, '*')))

# %%
base_folder <- "D:/kasanka-bats"
# Which days to track
days <- c("20211201", "20211207", "20211215")
camera_folders <- c()

for (day in days) {
  day_camera_folders <- sort(list.files(path = file.path(base_folder, day), pattern = "*", full.names = TRUE))
  camera_folders <- append(camera_folders, day_camera_folders)
}

# %%
n_camera_folders = []
for folder in camera_folders:
    tracks_file = os.path.join(folder, "raw_tracks.npy")
    if os.path.exists(tracks_file):
        # Skip videos that have already been tracked
        continue
    else:
        n_camera_folders.append(folder)

print("Videos to track...")
print(*n_camera_folders, sep='\n')
# Out:
# Videos to track...
# D:/kasanka-bats\20211221\BBC2
# D:/kasanka-bats\20211221\ChinyangaliB
# D:/kasanka-bats\20211221\FibweManagement
# D:/kasanka-bats\20211221\FibweParking
# D:/kasanka-bats\20211221\KKCamera
# D:/kasanka-bats\20211221\NotChinyangaliLocC
# D:/kasanka-bats\20211221\NotMusolaParking
# D:/kasanka-bats\20211221\NotMusolaPath

# %%
def track(camera_dict):
    camera_folder = camera_dict['camera_folder']
    first_frame = camera_dict['first_frame']
    max_frame = camera_dict['max_frame']
    print(f"{os.path.basename(camera_folder)} begun.")
    contours_files = sorted(
        glob.glob(os.path.join(camera_folder, 'contours-compressed-*.npy'))
    )
    if contours_files:
        contours_files = contours_files[1:]
        centers = np.load(os.path.join(camera_folder, 'centers.npy'), allow_pickle=True)
        sizes = np.load(os.path.join(camera_folder, 'size.npy'), allow_pickle=True)
        tracks_file = os.path.join(camera_folder, f'first_frame_{first_frame}_max_val_{max_frame}_raw_tracks.npy')
        raw_tracks = kbf.find_tracks(first_frame, centers, contours_files=contours_files, 
                                     sizes_list=sizes, tracks_file=tracks_file,
                                     max_frame=max_frame)
    else:
        print("Missing contour files.")

# %%
camera_dicts = []
for camera_folder in n_camera_folders:
    # To speed up processing, detections found in each observation are split
    # into 10 groups by time with 15 seconds of overlap in each group
    centers_file = os.path.join(camera_folder, 'centers.npy')
    centers = np.load(centers_file, allow_pickle=True)
    max_vals = np.linspace(0, len(centers), 10, dtype=int)[1:].tolist()
    max_vals[-1] = None
    min_vals = np.linspace(0, len(centers), 10, dtype=int)[:-1]
    # 15 second overlap
    min_vals[1:] = min_vals[1:] - 450
    for min_val, max_val in zip(min_vals, max_vals):
        min_val = np.max([min_val, 0])
        camera_dict = {'camera_folder': camera_folder,
                       'first_frame': min_val,
                       'max_frame': max_val}
        if max_val is None:
            tracks_basename = f'first_frame_{min_val:06d}_max_val_{max_val}_raw_tracks.npy'
        else:
            tracks_basename = f'first_frame_{min_val:06d}_max_val_{max_val:06d}_raw_tracks.npy'
        tracks_file = os.path.join(camera_folder, tracks_basename)
        if not os.path.exists(tracks_file):
            print(tracks_file)
            camera_dicts.append(camera_dict)
# Out:
# D:/kasanka-bats\20211221\BBC2\first_frame_000000_max_val_007069_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_006619_max_val_014139_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_013689_max_val_021209_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_020759_max_val_028279_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_027829_max_val_035349_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_034899_max_val_042419_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_041969_max_val_049489_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_049039_max_val_056559_raw_tracks.npy
# D:/kasanka-bats\20211221\BBC2\first_frame_056109_max_val_None_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_000000_max_val_009620_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_009170_max_val_019240_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_018790_max_val_028860_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_028410_max_val_038480_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_038030_max_val_048100_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_047650_max_val_057720_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_057270_max_val_067340_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_066890_max_val_076960_raw_tracks.npy
# D:/kasanka-bats\20211221\ChinyangaliB\first_frame_076510_max_val_None_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_000000_max_val_007875_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_007425_max_val_015750_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_015300_max_val_023625_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_023175_max_val_031500_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_031050_max_val_039375_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_038925_max_val_047250_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_046800_max_val_055125_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_054675_max_val_063000_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweManagement\first_frame_062550_max_val_None_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_000000_max_val_006770_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_006320_max_val_013540_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_013090_max_val_020310_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_019860_max_val_027080_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_026630_max_val_033850_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_033400_max_val_040620_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_040170_max_val_047390_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_046940_max_val_054160_raw_tracks.npy
# D:/kasanka-bats\20211221\FibweParking\first_frame_053710_max_val_None_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_000000_max_val_014160_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_013710_max_val_028320_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_027870_max_val_042480_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_042030_max_val_056640_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_056190_max_val_070800_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_070350_max_val_084960_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_084510_max_val_099120_raw_tracks.npy
# D:/kasanka-bats\20211221\KKCamera\first_frame_098670_max_val_113280_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_000000_max_val_007070_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_006620_max_val_014140_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_013690_max_val_021210_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_020760_max_val_028280_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_027830_max_val_035350_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_034900_max_val_042420_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_041970_max_val_049490_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_049040_max_val_056560_raw_tracks.npy
# D:/kasanka-bats\20211221\NotChinyangaliLocC\first_frame_056110_max_val_None_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_000000_max_val_007696_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_007246_max_val_015393_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_014943_max_val_023090_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_022640_max_val_030786_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_030336_max_val_038483_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_038033_max_val_046180_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_045730_max_val_053876_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_053426_max_val_061573_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaParking\first_frame_061123_max_val_None_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_000000_max_val_013375_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_012925_max_val_026750_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_026300_max_val_040126_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_039676_max_val_053501_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_053051_max_val_066876_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_066426_max_val_080252_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_079802_max_val_093627_raw_tracks.npy
# D:/kasanka-bats\20211221\NotMusolaPath\first_frame_093177_max_val_107002_raw_tracks.npy

# %%
#with Pool(processes=5) as pool:
#    pool.map(track, camera_dicts)
for camera_dict in camera_dicts:
    track(camera_dict)
# Out:
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-01.npy
# frame 0 processed.
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-02.npy
# frame 10000 processed.
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-04.npy
# frame 20000 processed.
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-05.npy
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-07.npy
# frame 30000 processed.
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-09.npy
# frame 40000 processed.
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-10.npy
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-12.npy
# frame 50000 processed.
# BBC2 final save.
# BBC2 begun.
# using D:/kasanka-bats\20211221\BBC2\contours-compressed-14.npy
# frame 60000 processed.
# BBC2 final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-01.npy
# frame 0 processed.
# ChinyangaliB final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-02.npy
# frame 10000 processed.
# ChinyangaliB final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-04.npy
# frame 20000 processed.
# ChinyangaliB final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-05.npy
# frame 30000 processed.
# ChinyangaliB final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-07.npy
# frame 40000 processed.
# ChinyangaliB final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-09.npy
# frame 50000 processed.
# ChinyangaliB final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-10.npy
# frame 60000 processed.
# ChinyangaliB final save.
# ChinyangaliB begun.
# using D:/kasanka-bats\20211221\ChinyangaliB\contours-compressed-12.npy
# frame 70000 processed.

# %% [markdown]
# ### Now connect the 10 sections of the observation that were tracked seperately together

# %%
def combine_overlapping_tracks(observation_folder, first_group=0, last_group=None, save=False):
    track_files = glob.glob(os.path.join(observation_folder, 'first_frame*.npy'))
    track_files = sorted(track_files, key=lambda f: int(f.split('_')[-6]))

    track_groups = []
    for file in track_files:
        track_groups.append(np.load(file, allow_pickle=True))
        
        
    for track_file in track_files:
        print(os.path.basename(track_file))
        
    first_overlap_frames = [int(f.split('_')[-6]) for f in track_files[1:]]
    first_overlap_frames.append(None)
    print(first_overlap_frames)
        
    all_tracks = []

    total_tracks = 0
    for group_ind, track_group in enumerate(track_groups[first_group:last_group]):
        if group_ind >= len(track_groups) -1:
            for track in track_group:
                if type(track['track']) == list:
                    track['track'] = np.stack(track['track'])
                    track['pos_index'] = np.stack(track['pos_index'])
                    if 'size' in track:
                        track['size'] = np.stack(track['size'])
                all_tracks.append(track)
            total_tracks += len(track_group)
            break

        for track_ind, track in enumerate(track_group):
            if track['first_frame'] < first_overlap_frames[first_group + group_ind]:
                all_tracks.append(track)


    all_tracks_file = os.path.join(observation_folder, 'raw_tracks.npy')
    if save:
        np.save(all_tracks_file, all_tracks)
        print('saved')

# %%
observation_folders = []
for folder in camera_folders:
    if not os.path.exists(os.path.join(folder, 'raw_tracks.npy')):
        observation_folders.append(folder)

# %%
for folder in observation_folders:
    combine_overlapping_tracks(folder, save=True)
