# %% [markdown]
# # Take the frame based detections and turn them into movement trajectories
# (For speed, uses multiprocessing and breaks up observations into 10 overlapping temporal groups to process seperately since tracks are much shorter in time than the total length of the obervations.)

# %%
import glob
import os

import matplotlib.pyplot as plt
from multiprocessing import Pool
import numpy as np

import bat_functions as kbf

# %%
base_folder = r"D:\kasanka-bats"
# Which day to track
day = "30-Oct-2020"
#"20211201"
#"20211207"
#"20211215"
camera_folders = sorted(glob.glob(os.path.join(base_folder, day, '*')))

# %%
base_folder = r"D:\kasanka-bats"
# Which days to track
days = ["30-Oct-2020"]
camera_folders = []

for day in days:
    print(day)
    day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, '*')))
    camera_folders.extend(day_camera_folders)
    #day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, 'MusolaTower*')))
    #camera_folders.extend(day_camera_folders)
    #day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, 'MusolaPath2*')))
    #camera_folders.extend(day_camera_folders)
    #day_camera_folders = sorted(glob.glob(os.path.join(base_folder, day, 'Sunset*')))
    #camera_folders.extend(day_camera_folders)
# Out:
# 30-Oct-2020

# %%
print(camera_folders)
# Out:
# ['D:\\kasanka-bats\\30-Oct-2020\\BBC', 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'D:\\kasanka-bats\\30-Oct-2020\\Musola Parking', 'D:\\kasanka-bats\\30-Oct-2020\\Musola Path', 'D:\\kasanka-bats\\30-Oct-2020\\Musola Tower', 'D:\\kasanka-bats\\30-Oct-2020\\Not Chingyangali', 'D:\\kasanka-bats\\30-Oct-2020\\Puku', 'D:\\kasanka-bats\\30-Oct-2020\\Sunset']

# %%
n_camera_folders = []
for folder in camera_folders:
    tracks_file = os.path.join(folder, "raw_tracks.npy")
    if os.path.exists(tracks_file):
        # Skip videos that have already been tracked
        continue
    else:
        n_camera_folders.append(folder)

print("Videos to track...")
print(*n_camera_folders, sep='\n')
# Out:
# Videos to track...
# D:\kasanka-bats\30-Oct-2020\BBC
# D:\kasanka-bats\30-Oct-2020\Chinyangali
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking
# D:\kasanka-bats\30-Oct-2020\Fibwe Public
# D:\kasanka-bats\30-Oct-2020\Musola Parking
# D:\kasanka-bats\30-Oct-2020\Musola Path
# D:\kasanka-bats\30-Oct-2020\Musola Tower
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali
# D:\kasanka-bats\30-Oct-2020\Puku
# D:\kasanka-bats\30-Oct-2020\Sunset

# %%
def track(camera_dict):
    camera_folder = camera_dict['camera_folder']
    if glob.glob(os.path.join(camera_folder, 'first_frame*.npy')):
        print(f"Skipping {os.path.basename(camera_folder)} since files exist.")
        return
    first_frame = camera_dict['first_frame']
    max_frame = camera_dict['max_frame']
    print(f"{os.path.basename(camera_folder)} begun.")
    contours_files = sorted(
        glob.glob(os.path.join(camera_folder, 'contours-compressed-*.npy'))
    )
    if contours_files:
        contours_files = contours_files[1:]
        centers = np.load(os.path.join(camera_folder, 'centers.npy'), allow_pickle=True)
        sizes = np.load(os.path.join(camera_folder, 'size.npy'), allow_pickle=True)
        tracks_file = os.path.join(camera_folder, f'first_frame_{first_frame}_max_val_{max_frame}_raw_tracks.npy')
        raw_tracks = kbf.find_tracks(first_frame, centers, contours_files=contours_files, 
                                     sizes_list=sizes, tracks_file=tracks_file,
                                     max_frame=max_frame)
    else:
        print("Missing contour files.")

# %%
camera_dicts = []
for camera_folder in n_camera_folders:
    # To speed up processing, detections found in each observation are split
    # into 10 groups by time with 15 seconds of overlap in each group
    centers_file = os.path.join(camera_folder, 'centers.npy')
    centers = np.load(centers_file, allow_pickle=True)
    max_vals = np.linspace(0, len(centers), 10, dtype=int)[1:].tolist()
    max_vals[-1] = None
    min_vals = np.linspace(0, len(centers), 10, dtype=int)[:-1]
    # 15 second overlap
    min_vals[1:] = min_vals[1:] - 450
    for min_val, max_val in zip(min_vals, max_vals):
        min_val = np.max([min_val, 0])
        camera_dict = {'camera_folder': camera_folder,
                       'first_frame': min_val,
                       'max_frame': max_val}
        if max_val is None:
            tracks_basename = f'first_frame_{min_val:06d}_max_val_{max_val}_raw_tracks.npy'
        else:
            tracks_basename = f'first_frame_{min_val:06d}_max_val_{max_val:06d}_raw_tracks.npy'
        tracks_file = os.path.join(camera_folder, tracks_basename)
        if not os.path.exists(tracks_file):
            print(tracks_file)
            camera_dicts.append(camera_dict)
# Out:
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_000000_max_val_005653_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_005203_max_val_011307_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_010857_max_val_016961_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_016511_max_val_022615_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_022165_max_val_028269_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_027819_max_val_033923_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_033473_max_val_039577_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_039127_max_val_045231_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\BBC\first_frame_044781_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_000000_max_val_004830_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_004380_max_val_009660_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_009210_max_val_014490_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_014040_max_val_019320_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_018870_max_val_024150_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_023700_max_val_028980_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_028530_max_val_033810_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_033360_max_val_038640_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Chinyangali\first_frame_038190_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_000000_max_val_004513_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_004063_max_val_009026_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_008576_max_val_013540_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_013090_max_val_018053_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_017603_max_val_022566_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_022116_max_val_027080_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_026630_max_val_031593_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_031143_max_val_036106_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Parking\first_frame_035656_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_000000_max_val_004057_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_003607_max_val_008115_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_007665_max_val_012172_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_011722_max_val_016230_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_015780_max_val_020287_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_019837_max_val_024345_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_023895_max_val_028402_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_027952_max_val_032460_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Fibwe Public\first_frame_032010_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_000000_max_val_003887_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_003437_max_val_007774_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_007324_max_val_011661_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_011211_max_val_015548_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_015098_max_val_019435_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_018985_max_val_023322_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_022872_max_val_027209_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_026759_max_val_031096_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Parking\first_frame_030646_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_000000_max_val_004016_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_003566_max_val_008033_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_007583_max_val_012050_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_011600_max_val_016066_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_015616_max_val_020083_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_019633_max_val_024100_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_023650_max_val_028116_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_027666_max_val_032133_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Path\first_frame_031683_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_000000_max_val_004726_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_004276_max_val_009453_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_009003_max_val_014179_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_013729_max_val_018906_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_018456_max_val_023632_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_023182_max_val_028359_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_027909_max_val_033085_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_032635_max_val_037812_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Musola Tower\first_frame_037362_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_000000_max_val_002356_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_001906_max_val_004713_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_004263_max_val_007069_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_006619_max_val_009426_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_008976_max_val_011782_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_011332_max_val_014139_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_013689_max_val_016495_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_016045_max_val_018852_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Not Chingyangali\first_frame_018402_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_000000_max_val_003206_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_002756_max_val_006413_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_005963_max_val_009620_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_009170_max_val_012826_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_012376_max_val_016033_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_015583_max_val_019240_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_018790_max_val_022446_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_021996_max_val_025653_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Puku\first_frame_025203_max_val_None_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_000000_max_val_003206_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_002756_max_val_006413_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_005963_max_val_009620_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_009170_max_val_012826_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_012376_max_val_016033_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_015583_max_val_019240_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_018790_max_val_022446_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_021996_max_val_025653_raw_tracks.npy
# D:\kasanka-bats\30-Oct-2020\Sunset\first_frame_025203_max_val_None_raw_tracks.npy

# %%
print(camera_dicts)
#with Pool(processes=5) as pool:
#    pool.map(track, camera_dicts)
# Out:
# [{'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 0, 'max_frame': 5653}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 5203, 'max_frame': 11307}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 10857, 'max_frame': 16961}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 16511, 'max_frame': 22615}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 22165, 'max_frame': 28269}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 27819, 'max_frame': 33923}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 33473, 'max_frame': 39577}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 39127, 'max_frame': 45231}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\BBC', 'first_frame': 44781, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 0, 'max_frame': 4830}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 4380, 'max_frame': 9660}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 9210, 'max_frame': 14490}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 14040, 'max_frame': 19320}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 18870, 'max_frame': 24150}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 23700, 'max_frame': 28980}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 28530, 'max_frame': 33810}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 33360, 'max_frame': 38640}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'first_frame': 38190, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 0, 'max_frame': 4513}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 4063, 'max_frame': 9026}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 8576, 'max_frame': 13540}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 13090, 'max_frame': 18053}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 17603, 'max_frame': 22566}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 22116, 'max_frame': 27080}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 26630, 'max_frame': 31593}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 31143, 'max_frame': 36106}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'first_frame': 35656, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 0, 'max_frame': 4057}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 3607, 'max_frame': 8115}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 7665, 'max_frame': 12172}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 11722, 'max_frame': 16230}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 15780, 'max_frame': 20287}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 19837, 'max_frame': 24345}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 23895, 'max_frame': 28402}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 27952, 'max_frame': 32460}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'first_frame': 32010, 'max_frame': None}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Musola Parking', 'first_frame': 0, 'max_frame': 3887}, {'camera_folder': 'D:\\kasanka-bats\\30-Oct-2020\\Musola Parking', 'first_frame': 3437, 'max_frame': 7774}, {'camera_fold ...

# %%
for camera_dict in camera_dicts:
    track(camera_dict)
# Out:
# BBC begun.
# using D:\kasanka-bats\30-Oct-2020\BBC\contours-compressed-01.npy
# frame 0 processed.
# BBC final save.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Skipping BBC since files exist.
# Chinyangali begun.
# using D:\kasanka-bats\30-Oct-2020\Chinyangali\contours-compressed-01.npy
# frame 0 processed.
# Chinyangali final save.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Skipping Chinyangali since files exist.
# Fibwe Parking begun.
# using D:\kasanka-bats\30-Oct-2020\Fibwe Parking\contours-compressed-01.npy
# frame 0 processed.
# Fibwe Parking final save.
# Skipping Fibwe Parking since files exist.
# Skipping Fibwe Parking since files exist.
# Skipping Fibwe Parking since files exist.
# Skipping Fibwe Parking since files exist.
# Skipping Fibwe Parking since files exist.
# Skipping Fibwe Parking since files exist.
# Skipping Fibwe Parking since files exist.
# Skipping Fibwe Parking since files exist.
# Fibwe Public begun.
# using D:\kasanka-bats\30-Oct-2020\Fibwe Public\contours-compressed-01.npy
# frame 0 processed.
# Fibwe Public final save.
# Skipping Fibwe Public since files exist.
# Skipping Fibwe Public since files exist.
# Skipping Fibwe Public since files exist.
# Skipping Fibwe Public since files exist.
# Skipping Fibwe Public since files exist.
# Skipping Fibwe Public since files exist.
# Skipping Fibwe Public since files exist.
# Skipping Fibwe Public since files exist.
# Musola Parking begun.
# using D:\kasanka-bats\30-Oct-2020\Musola Parking\contours-compressed-01.npy
# frame 0 processed.
# Musola Parking final save.
# Skipping Musola Parking since files exist.
# Skipping Musola Parking since files exist.
# Skipping Musola Parking since files exist.
# Skipping Musola Parking since files exist.
# Skipping Musola Parking since files exist.
# Skipping Musola Parking since files exist.
# Skipping Musola Parking since files exist.
# Skipping Musola Parking since files exist.
# Musola Path begun.
# using D:\kasanka-bats\30-Oct-2020\Musola Path\contours-compressed-01.npy
# frame 0 processed.
# Musola Path final save.
# Skipping Musola Path since files exist.
# Skipping Musola Path since files exist.
# Skipping Musola Path since files exist.
# Skipping Musola Path since files exist.
# Skipping Musola Path since files exist.
# Skipping Musola Path since files exist.
# Skipping Musola Path since files exist.
# Skipping Musola Path since files exist.
# Musola Tower begun.
# using D:\kasanka-bats\30-Oct-2020\Musola Tower\contours-compressed-01.npy
# frame 0 processed.
# Musola Tower final save.
# Skipping Musola Tower since files exist.
# Skipping Musola Tower since files exist.
# Skipping Musola Tower since files exist.
# Skipping Musola Tower since files exist.
# Skipping Musola Tower since files exist.
# Skipping Musola Tower since files exist.
# Skipping Musola Tower since files exist.
# Skipping Musola Tower since files exist.
# Not Chingyangali begun.
# using D:\kasanka-bats\30-Oct-2020\Not Chingyangali\contours-compressed-01.npy
# frame 0 processed.
# Not Chingyangali final save.
# Skipping Not Chingyangali since files exist.
# Skipping Not Chingyangali since files exist.
# Skipping Not Chingyangali since files exist.
# Skipping Not Chingyangali since files exist.
# Skipping Not Chingyangali since files exist.
# Skipping Not Chingyangali since files exist.
# Skipping Not Chingyangali since files exist.
# Skipping Not Chingyangali since files exist.
# Puku begun.
# using D:\kasanka-bats\30-Oct-2020\Puku\contours-compressed-01.npy
# frame 0 processed.
# Puku final save.
# Skipping Puku since files exist.
# Skipping Puku since files exist.
# Skipping Puku since files exist.
# Skipping Puku since files exist.
# Skipping Puku since files exist.
# Skipping Puku since files exist.
# Skipping Puku since files exist.
# Skipping Puku since files exist.
# Sunset begun.
# using D:\kasanka-bats\30-Oct-2020\Sunset\contours-compressed-01.npy
# frame 0 processed.
# Sunset final save.
# Skipping Sunset since files exist.
# Skipping Sunset since files exist.
# Skipping Sunset since files exist.
# Skipping Sunset since files exist.
# Skipping Sunset since files exist.
# Skipping Sunset since files exist.
# Skipping Sunset since files exist.
# Skipping Sunset since files exist.

# %% [markdown]
# ### Now connect the 10 sections of the observation that were tracked seperately together

# %%
def combine_overlapping_tracks(observation_folder, first_group=0, last_group=None, save=False):
    track_files = glob.glob(os.path.join(observation_folder, 'first_frame*.npy'))
    track_files = sorted(track_files, key=lambda f: int(f.split('_')[-6]))

    track_groups = []
    for file in track_files:
        track_groups.append(np.load(file, allow_pickle=True))
        
        
    for track_file in track_files:
        print(os.path.basename(track_file))
        
    first_overlap_frames = [int(f.split('_')[-6]) for f in track_files[1:]]
    first_overlap_frames.append(None)
    print(first_overlap_frames)
        
    all_tracks = []

    total_tracks = 0
    for group_ind, track_group in enumerate(track_groups[first_group:last_group]):
        if group_ind >= len(track_groups) -1:
            for track in track_group:
                if type(track['track']) == list:
                    track['track'] = np.stack(track['track'])
                    track['pos_index'] = np.stack(track['pos_index'])
                    if 'size' in track:
                        track['size'] = np.stack(track['size'])
                all_tracks.append(track)
            total_tracks += len(track_group)
            break

        for track_ind, track in enumerate(track_group):
            if track['first_frame'] < first_overlap_frames[first_group + group_ind]:
                all_tracks.append(track)


    all_tracks_file = os.path.join(observation_folder, 'raw_tracks.npy')
    if save:
        np.save(all_tracks_file, all_tracks)
        print('saved')

# %%
observation_folders = []
for folder in camera_folders:
    if not os.path.exists(os.path.join(folder, 'first_frame*.npy')):
        observation_folders.append(folder)

# %%
print(observation_folders)
# Out:
# ['D:\\kasanka-bats\\30-Oct-2020\\BBC', 'D:\\kasanka-bats\\30-Oct-2020\\Chinyangali', 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Parking', 'D:\\kasanka-bats\\30-Oct-2020\\Fibwe Public', 'D:\\kasanka-bats\\30-Oct-2020\\Musola Parking', 'D:\\kasanka-bats\\30-Oct-2020\\Musola Path', 'D:\\kasanka-bats\\30-Oct-2020\\Musola Tower', 'D:\\kasanka-bats\\30-Oct-2020\\Not Chingyangali', 'D:\\kasanka-bats\\30-Oct-2020\\Puku', 'D:\\kasanka-bats\\30-Oct-2020\\Sunset']

# %%
for folder in observation_folders:
    combine_overlapping_tracks(folder, save=True)
# Out:
# first_frame_0_max_val_5653_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_4830_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_4513_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_4057_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_3887_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_4016_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_4726_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_2356_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_3206_raw_tracks.npy
# [None]
# saved
# first_frame_0_max_val_3206_raw_tracks.npy
# [None]
# saved
