# %%
import ffmpeg

# List of input video paths
input_paths = [
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH020023.MP4",
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH030023.MP4"
    
    r"E:\KasankaCameras\20221213\3 Chinyangali\GH050476.MP4",
    r"E:\KasankaCameras\20221213\3 Chinyangali\GH060476.MP4"
    # Add more paths as needed
]

for input_path in input_paths:
    # Load the input stream
    stream = ffmpeg.input(input_path)

    # Apply vertical flip
    stream = ffmpeg.vflip(stream)

    # Construct the output file path by appending "_flipped" before the file extension
    output_path = input_path.replace(".MP4", "_flipped.MP4")

    # Output the flipped video
    stream = ffmpeg.output(stream, output_path)

    # Run the FFmpeg process
    ffmpeg.run(stream)

# %%
import ffmpeg

# List of input video paths
input_paths = [
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH020023.MP4",
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH030023.MP4"
    
    r"E:\KasankaCameras\20221213\6 Sunset\GH020747.MP4",
    r"E:\KasankaCameras\20221213\6 Sunset\GH030747.MP4",
    r"E:\KasankaCameras\20221213\6 Sunset\GH040747.MP4"
    
    # r"E:\KasankaCameras\20221219\3 Chinyangali\GH050477.MP4"
    # Add more paths as needed
]

for input_path in input_paths:
    # Load the input stream
    stream = ffmpeg.input(input_path)

    # Apply vertical flip
    stream = ffmpeg.vflip(stream)

    # Construct the output file path by appending "_flipped" before the file extension
    output_path = input_path.replace(".MP4", "_flipped.MP4")

    # Output the flipped video
    stream = ffmpeg.output(stream, output_path)

    # Run the FFmpeg process
    ffmpeg.run(stream)

# %%
import ffmpeg

# List of input video paths
input_paths = [
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH020023.MP4",
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH030023.MP4"
    
    r"E:\KasankaCameras\20221213\8 Musola Path\GH050006.MP4",
    r"E:\KasankaCameras\20221213\8 Musola Path\GH060006.MP4",
    r"E:\KasankaCameras\20221213\8 Musola Path\GH070006.MP4"
    
    # r"E:\KasankaCameras\20221219\3 Chinyangali\GH050477.MP4"
    # Add more paths as needed
]

for input_path in input_paths:
    # Load the input stream
    stream = ffmpeg.input(input_path)

    # Apply vertical flip
    stream = ffmpeg.vflip(stream)

    # Construct the output file path by appending "_flipped" before the file extension
    output_path = input_path.replace(".MP4", "_flipped.MP4")

    # Output the flipped video
    stream = ffmpeg.output(stream, output_path)

    # Run the FFmpeg process
    ffmpeg.run(stream)

# %%
import ffmpeg

# List of input video paths
input_paths = [
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH020023.MP4",
    #r"F:\KasankaCameras\16-Nov-2020\Fibwe Parking\GH030023.MP4"
    
    # r"E:\KasankaCameras\20221219\5 Puku\GH020050.MP4",
    # r"E:\KasankaCameras\20221219\5 Puku\GH030050.MP4",
    
    r"E:\KasankaCameras\20221219\6 Sunset\GH010748.MP4",
    r"E:\KasankaCameras\20221219\6 Sunset\GH020748.MP4"
    # r"E:\KasankaCameras\20221219\3 Chinyangali\GH050477.MP4"
    # Add more paths as needed
]

for input_path in input_paths:
    # Load the input stream
    stream = ffmpeg.input(input_path)
    
    # Apply vertical flip
    stream = ffmpeg.vflip(stream)

    # Construct the output file path by appending "_flipped" before the file extension
    output_path = input_path.replace(".MP4", "_flipped.MP4")

    # Output the flipped video
    stream = ffmpeg.output(stream, output_path)

    # Run the FFmpeg process
    ffmpeg.run(stream)
